# %%
import uuid
from datetime import datetime
import pandas as pd


d=pd.date_range(start=datetime.now().date().isoformat() , periods=3, freq="D")
print(d)
start = pd.to_datetime(datetime.now().date().isoformat())
end = start + pd.DateOffset(months=3)
print(end)
# Out:
# DatetimeIndex(['2026-03-03', '2026-03-04', '2026-03-05'], dtype='datetime64[ns]', freq='D')
# 2026-06-03 00:00:00

# %%
from datetime import datetime
import pandas as pd
freq = 'W-MON,WED,FRI' 
liste = []
for i in pd.date_range(start='2026-03-02', periods=3, freq='56h'):
    # .extend() fügt die einzelnen Elemente der Range zur Liste hinzu
    liste.extend(pd.date_range(start=i, periods=3, freq='56h'))

print(liste)
print(liste)
# Out:
# [Timestamp('2026-03-02 00:00:00'), Timestamp('2026-03-04 08:00:00'), Timestamp('2026-03-06 16:00:00'), Timestamp('2026-03-04 08:00:00'), Timestamp('2026-03-06 16:00:00'), Timestamp('2026-03-09 00:00:00'), Timestamp('2026-03-06 16:00:00'), Timestamp('2026-03-09 00:00:00'), Timestamp('2026-03-11 08:00:00')]
# [Timestamp('2026-03-02 00:00:00'), Timestamp('2026-03-04 08:00:00'), Timestamp('2026-03-06 16:00:00'), Timestamp('2026-03-04 08:00:00'), Timestamp('2026-03-06 16:00:00'), Timestamp('2026-03-09 00:00:00'), Timestamp('2026-03-06 16:00:00'), Timestamp('2026-03-09 00:00:00'), Timestamp('2026-03-11 08:00:00')]
